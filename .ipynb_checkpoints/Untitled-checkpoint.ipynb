# %% [markdown]
# ### 트레인, 테스트 데이터
#
# train 훈련용(7) X_train 학습용 문제데이터, y_test 학습용 방법 데이터
#
# test 테스트용(3) X_train, y_test

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# 학습이 과할수록 복잡도가 올라감(과대적합)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 깊이가 깊어질수록 모델의 복잡도 증가->과대적합 확률 올라감
# Decision Tree는 과대적합의 확률이 높은 모델임

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 하드보팅
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 소프트보팅
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 랜덤포레스트
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - 공통점: 같은 모델 사용

# %% [markdown]
# ![image.png](attachment:image.png)
